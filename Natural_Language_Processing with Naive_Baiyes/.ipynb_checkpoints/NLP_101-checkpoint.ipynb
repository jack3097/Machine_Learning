# %% [markdown]
# ### Concepts on NLP

# %% [raw]
# 1. Tokenization - Splitting the senctence into words and making single entities of it
# 2. Cleaning Text - Removing words that don't have significance such as "and,the,is,am,are" and then converting to lower case
#                    and then using Regular Expressions to filter words
# 3. Stemming - Converting each word to its root word is called stemming. For example "go, going, gone" have same root word "go".
# 4. Lemmitization - Similar to stemming, changes to its root of words
# 5. Bag of Words - Converts group of words into a matrix, showing each words frequency
# 6. TF-IDF - Term Frequency-Inverse Document Frequency, forms a matrix and shows TF-IDF of each words

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
paragraph = """Harry Potter is the most miserable, lonely boy you can imagine. He’s shunned by his relatives, the Dursley’s, that have raised him since he was an infant. He’s forced to live in the cupboard under the stairs, forced to wear his cousin Dudley’s hand-me-down clothes, and forced to go to his neighbour’s house when the rest of the family is doing something fun. Yes, he’s just about as miserable as you can get.

Harry’s world gets turned upside down on his 11th birthday, however. A giant, Hagrid, informs Harry that he’s really a wizard, and will soon be attending Hogwarts School of Witchcraft and Wizardry. Harry also learns that, in the wizarding world, he’s a hero. When he was an infant, the evil Lord Voldemort killed his parents and then tried to kill Harry too. What’s so amazing to everyone is that Harry survived, and allegedly destroyed Voldemort in the process.

When Harry hears all this, he doesn’t know what to think. However, everything Hagrid tells him turns out to be true, and with a joyful heart Harry starts wizarding school in September. He quickly becomes best friends with a boy named Ron Weasley, and before they even make it to Christmas, they break tons of school rules when they attack a troll and prevent it from killing fellow student Hermione Granger. After the troll incident, the three become inseparable, and Harry is amazed to have found such great friends. He is constantly busy trying to stay on top of the mounds of homework, as well as participating in weekly Quidditch practices. Quidditch is a popular sport among wizards and Harry is the youngest Quidditch player in over a century. It's also a game Harry loves more than anything else at school.

As the year progresses, the three friends set out to solve the mystery of the gigantic three-headed dog that is guarding something in a deserted corridor in the school. They figure out that a very valuable object, the Sorcerer’s Stone, is being hidden in the school, although they don’t know why. When one of the professors starts acting as if he’s trying to steal it, they quickly take action to circumvent the theft.

Things come to a head when they sneak past the vicious, three-headed dog and go down into the bowels of the school, determined to save the stone. Ron and Hermione help Harry get through the challenges set forth to stop the thief, but Harry must go on alone to battle the professor. When he finally gets to the last room, however, he’s astonished to find someone else entirely.

Harry is forced to do battle with the wizard that tried to kill him so many years before, Lord Voldemort. He’s able to save the Sorcerer’s Stone, although he’s almost killed in process. The school headmaster, Dumbledore, arrives just in time to save Harry.

The school year ends spectacularly. Harry, Ron, and Hermione are honored for their service to the school, and Harry leaves to go back to the Dursley’s for the summer feeling as if he’s finally found a place where he really belongs."""

# %%
paragraph = paragraph.lower()

# %%
paragraph
# Out:
# "harry potter is the most miserable, lonely boy you can imagine. he’s shunned by his relatives, the dursley’s, that have raised him since he was an infant. he’s forced to live in the cupboard under the stairs, forced to wear his cousin dudley’s hand-me-down clothes, and forced to go to his neighbour’s house when the rest of the family is doing something fun. yes, he’s just about as miserable as you can get.\n\nharry’s world gets turned upside down on his 11th birthday, however. a giant, hagrid, informs harry that he’s really a wizard, and will soon be attending hogwarts school of witchcraft and wizardry. harry also learns that, in the wizarding world, he’s a hero. when he was an infant, the evil lord voldemort killed his parents and then tried to kill harry too. what’s so amazing to everyone is that harry survived, and allegedly destroyed voldemort in the process.\n\nwhen harry hears all this, he doesn’t know what to think. however, everything hagrid tells him turns out to be true, and with a joyful heart harry starts wizarding school in september. he quickly becomes best friends with a boy named ron weasley, and before they even make it to christmas, they break tons of school rules when they attack a troll and prevent it from killing fellow student hermione granger. after the troll incident, the three become inseparable, and harry is amazed to have found such great friends. he is constantly busy trying to stay on top of the mounds of homework, as well as participating in weekly quidditch practices. quidditch is a popular sport among wizards and harry is the youngest quidditch player in over a century. it's also a game harry loves more than anything else at school.\n\nas the year progresses, the three friends set out to solve the mystery of the gigantic three-headed dog that is guarding something in a deserted corridor in the school. they figure out that a very valuable object, the sorcerer’s stone, is being hidden in the school, although they don’t know why. when one of the professors starts acting as if he’s trying to steal it, they quickly take action to circumvent the theft.\n\nthings come to a head when they sneak past the vicious, three-headed dog and go down into the bowels of the school, determined to save the stone. ron and hermione help harry get through the challenges set forth to stop the thief, but harry must go on alone to battle the professor. when he finally gets to the last room, however, he’s astonished to find someone else entirely.\n\nharry is forced to do battle with the wizard that tried to kill him so many years before, lord voldemort. he’s able to save the sorcerer’s stone, although he’s almost killed in process. the school headmaster, dumbledore, arrives just in time to save harry.\n\nthe school year ends spectacularly. harry, ron, and hermione are honored for their service to the school, and harry leaves to go back to the dursley’s for the summer feeling as if he’s finally found a place where he really belongs."

# %%
#Tokenizing the sentences
sentences = nltk.sent_tokenize(paragraph)
sentences
# Out:
# ['harry potter is the most miserable, lonely boy you can imagine.',
#  'he’s shunned by his relatives, the dursley’s, that have raised him since he was an infant.',
#  'he’s forced to live in the cupboard under the stairs, forced to wear his cousin dudley’s hand-me-down clothes, and forced to go to his neighbour’s house when the rest of the family is doing something fun.',
#  'yes, he’s just about as miserable as you can get.',
#  'harry’s world gets turned upside down on his 11th birthday, however.',
#  'a giant, hagrid, informs harry that he’s really a wizard, and will soon be attending hogwarts school of witchcraft and wizardry.',
#  'harry also learns that, in the wizarding world, he’s a hero.',
#  'when he was an infant, the evil lord voldemort killed his parents and then tried to kill harry too.',
#  'what’s so amazing to everyone is that harry survived, and allegedly destroyed voldemort in the process.',
#  'when harry hears all this, he doesn’t know what to think.',
#  'however, everything hagrid tells him turns out to be true, and with a joyful heart harry starts wizarding school in september.',
#  'he quickly becomes best friends with a boy named ron weasley, and before they even make it to christmas, they break tons of school rules when they attack a troll and prevent it from killing fellow student hermione granger.',
#  'after the troll incident, the three become inseparable, and harry is amazed to have found such great friends.',
#  'he is constantly busy trying to stay on top of the mounds of homework, as well as participating in weekly quidditch practices.',
#  'quidditch is a popular sport among wizards and harry is the youngest quidditch player in over a century.',
#  "it's also a game harry loves more than anything else at school.",
#  'as the year progresses, the three friends set out to solve the mystery of the gigantic three-headed dog that is guarding something in a deserted corridor in the school.',
#  'they figure out that a very valuable object, the sorcerer’s stone, is being hidden in the school, although they don’t know why.',
#  'when one of the professors starts acting as if he’s trying to steal it, they quickly take action to circumvent the theft.',
#  'things come to a head when they sneak past the vicious, three-headed dog and go down into the bowels of the school, determined to save the stone.',
#  'ron and hermione help harry get through the challenges set forth to stop the thief, but harry must go on alone to battle the professor.',
#  'when he finally gets to the last room, however, he’s astonished to find someone else entirely.',
#  'harry is forced to do battle with the wizard that tried to kill him so many years before, lord voldemort.',
#  'he’s able to save the sorcerer’s stone, although he’s almost killed in process.',
#  'the school headmaster, dumbledore, arrives just in time to save harry.',
#  'the school year ends spectacularly.',
#  'harry, ron, and hermione are honored for their service to the school, and harry leaves to go back to the dursley’s for the summer feeling as if he’s finally found a place where he really belongs.']

# %%
len(sentences)
# Out:
# 27

# %%
#tokenizing the words
words = nltk.word_tokenize(paragraph)
words
# Out:
# ['harry',
#  'potter',
#  'is',
#  'the',
#  'most',
#  'miserable',
#  ',',
#  'lonely',
#  'boy',
#  'you',
#  'can',
#  'imagine',
#  '.',
#  'he',
#  '’',
#  's',
#  'shunned',
#  'by',
#  'his',
#  'relatives',
#  ',',
#  'the',
#  'dursley',
#  '’',
#  's',
#  ',',
#  'that',
#  'have',
#  'raised',
#  'him',
#  'since',
#  'he',
#  'was',
#  'an',
#  'infant',
#  '.',
#  'he',
#  '’',
#  's',
#  'forced',
#  'to',
#  'live',
#  'in',
#  'the',
#  'cupboard',
#  'under',
#  'the',
#  'stairs',
#  ',',
#  'forced',
#  'to',
#  'wear',
#  'his',
#  'cousin',
#  'dudley',
#  '’',
#  's',
#  'hand-me-down',
#  'clothes',
#  ',',
#  'and',
#  'forced',
#  'to',
#  'go',
#  'to',
#  'his',
#  'neighbour',
#  '’',
#  's',
#  'house',
#  'when',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'family',
#  'is',
#  'doing',
#  'something',
#  'fun',
#  '.',
#  'yes',
#  ',',
#  'he',
#  '’',
#  's',
#  'just',
#  'about',
#  'as',
#  'miserable',
#  'as',
#  'you',
#  'can',
#  'get',
#  '.',
#  'harry',
#  '’',
#  's',
#  'world',
#  'gets',
#  'turned',
#  'upside',
#  'down',
#  'on',
#  'his',
#  '11th',
#  'birthday',
#  ',',
#  'however',
#  '.',
#  'a',
#  'giant',
#  ',',
#  'hagrid',
#  ',',
#  'informs',
#  'harry',
#  'that',
#  'he',
#  '’',
#  's',
#  'really',
#  'a',
#  'wizard',
#  ',',
#  'and',
#  'will',
#  'soon',
#  'be',
#  'attending',
#  'hogwarts',
#  'school',
#  'of',
#  'witchcraft',
#  'and',
#  'wizardry',
#  '.',
#  'harry',
#  'also',
#  'learns',
#  'that',
#  ',',
#  'in',
#  'the',
#  'wizarding',
#  'world',
#  ',',
#  'he',
#  '’',
#  's',
#  'a',
#  'hero',
#  '.',
#  'when',
#  'he',
#  'was',
#  'an',
#  'infant',
#  ',',
#  'the',
#  'evil',
#  'lord',
#  'voldemort',
#  'killed',
#  'his',
#  'parents',
#  'and',
#  'then',
#  'tried',
#  'to',
#  'kill',
#  'harry',
#  'too',
#  '.',
#  'what',
#  '’',
#  's',
#  'so',
#  'amazing',
#  'to',
#  'everyone',
#  'is',
#  'that',
#  'harry',
#  'survived',
#  ',',
#  'and',
#  'allegedly',
#  'destroyed',
#  'voldemort',
#  'in',
#  'the',
#  'process',
#  '.',
#  'when',
#  'harry',
#  'hears',
#  'all',
#  'this',
#  ',',
#  'he',
#  'doesn',
#  '’',
#  't',
#  'know',
#  'what',
#  'to',
#  'think',
#  '.',
#  'however',
#  ',',
#  'everything',
#  'hagrid',
#  'tells',
#  'him',
#  'turns',
#  'out',
#  'to',
#  'be',
#  'true',
#  ',',
#  'and',
#  'with',
#  'a',
#  'joyful',
#  'heart',
#  'harry',
#  'starts',
#  'wizarding',
#  'school',
#  'in',
#  'september',
#  '.',
#  'he',
#  'quickly',
#  'becomes',
#  'best',
#  'friends',
#  'with',
#  'a',
#  'boy',
#  'named',
#  'ron',
#  'weasley',
#  ',',
#  'and',
#  'before',
#  'they',
#  'even',
#  'make',
#  'it',
#  'to',
#  'christmas',
#  ',',
#  'they',
#  'break',
#  'tons',
#  'of',
#  'school',
#  'rules',
#  'when',
#  'they',
#  'attack',
#  'a',
#  'troll',
#  'and',
#  'prevent',
#  'it',
#  'from',
#  'killing',
#  'fellow',
#  'student',
#  'hermione',
#  'granger',
#  '.',
#  'after',
#  'the',
#  'troll',
#  'incident',
#  ',',
#  'the',
#  'three',
#  'become',
#  'inseparable',
#  ',',
#  'and',
#  'harry',
#  'is',
#  'amazed',
#  'to',
#  'have',
#  'found',
#  'such',
#  'great',
#  'friends',
#  '.',
#  'he',
#  'is',
#  'constantly',
#  'busy',
#  'trying',
#  'to',
#  'stay',
#  'on',
#  'top',
#  'of',
#  'the',
#  'mounds',
#  'of',
#  'homework',
#  ',',
#  'as',
#  'well',
#  'as',
#  'participating',
#  'in',
#  'weekly',
#  'quidditch',
#  'practices',
#  '.',
#  'quidditch',
#  'is',
#  'a',
#  'popular',
#  'sport',
#  'among',
#  'wizards',
#  'and',
#  'harry',
#  'is',
#  'the',
#  'youngest',
#  'quidditch',
#  'player',
#  'in',
#  'over',
#  'a',
#  'century',
#  '.',
#  'it',
#  "'s",
#  'also',
#  'a',
#  'game',
#  'harry',
#  'loves',
#  'more',
#  'than',
#  'anything',
#  'else',
#  'at',
#  'school',
#  '.',
#  'as',
#  'the',
#  'year',
#  'progresses',
#  ',',
#  'the',
#  'three',
#  'friends',
#  'set',
#  'out',
#  'to',
#  'solve',
#  'the',
#  'mystery',
#  'of',
#  'the',
#  'gigantic',
#  'three-headed',
#  'dog',
#  'that',
#  'is',
#  'guarding',
#  'something',
#  'in',
#  'a',
#  'deserted',
#  'corridor',
#  'in',
#  'the',
#  'school',
#  '.',
#  'they',
#  'figure',
#  'out',
#  'that',
#  'a',
#  'very',
#  'valuable',
#  'object',
#  ',',
#  'the',
#  'sorcerer',
#  '’',
#  's',
#  'stone',
#  ',',
#  'is',
#  'being',
#  'hidden',
#  'in',
#  'the',
#  'school',
#  ',',
#  'although',
#  'they',
#  'don',
#  '’',
#  't',
#  'know',
#  'why',
#  '.',
#  'when',
#  'one',
#  'of',
#  'the',
#  'professors',
#  'starts',
#  'acting',
#  'as',
#  'if',
#  'he',
#  '’',
#  's',
#  'trying',
#  'to',
#  'steal',
#  'it',
#  ',',
#  'they',
#  'quickly',
#  'take',
#  'action',
#  'to',
#  'circumvent',
#  'the',
#  'theft',
#  '.',
#  'things',
#  'come',
#  'to',
#  'a',
#  'head',
#  'when',
#  'they',
#  'sneak',
#  'past',
#  'the',
#  'vicious',
#  ',',
#  'three-headed',
#  'dog',
#  'and',
#  'go',
#  'down',
#  'into',
#  'the',
#  'bowels',
#  'of',
#  'the',
#  'school',
#  ',',
#  'determined',
#  'to',
#  'save',
#  'the',
#  'stone',
#  '.',
#  'ron',
#  'and',
#  'hermione',
#  'help',
#  'harry',
#  'get',
#  'through',
#  'the',
#  'challenges',
#  'set',
#  'forth',
#  'to',
#  'stop',
#  'the',
#  'thief',
#  ',',
#  'but',
#  'harry',
#  'must',
#  'go',
#  'on',
#  'alone',
#  'to',
#  'battle',
#  'the',
#  'professor',
#  '.',
#  'when',
#  'he',
#  'finally',
#  'gets',
#  'to',
#  'the',
#  'last',
#  'room',
#  ',',
#  'however',
#  ',',
#  'he',
#  '’',
#  's',
#  'astonished',
#  'to',
#  'find',
#  'someone',
#  'else',
#  'entirely',
#  '.',
#  'harry',
#  'is',
#  'forced',
#  'to',
#  'do',
#  'battle',
#  'with',
#  'the',
#  'wizard',
#  'that',
#  'tried',
#  'to',
#  'kill',
#  'him',
#  'so',
#  'many',
#  'years',
#  'before',
#  ',',
#  'lord',
#  'voldemort',
#  '.',
#  'he',
#  '’',
#  's',
#  'able',
#  'to',
#  'save',
#  'the',
#  'sorcerer',
#  '’',
#  's',
#  'stone',
#  ',',
#  'although',
#  'he',
#  '’',
#  's',
#  'almost',
#  'killed',
#  'in',
#  'process',
#  '.',
#  'the',
#  'school',
#  'headmaster',
#  ',',
#  'dumbledore',
#  ',',
#  'arrives',
#  'just',
#  'in',
#  'time',
#  'to',
#  'save',
#  'harry',
#  '.',
#  'the',
#  'school',
#  'year',
#  'ends',
#  'spectacularly',
#  '.',
#  'harry',
#  ',',
#  'ron',
#  ',',
#  'and',
#  'hermione',
#  'are',
#  'honored',
#  'for',
#  'their',
#  'service',
#  'to',
#  'the',
#  'school',
#  ',',
#  'and',
#  'harry',
#  'leaves',
#  'to',
#  'go',
#  'back',
#  'to',
#  'the',
#  'dursley',
#  '’',
#  's',
#  'for',
#  'the',
#  'summer',
#  'feeling',
#  'as',
#  'if',
#  'he',
#  '’',
#  's',
#  'finally',
#  'found',
#  'a',
#  'place',
#  'where',
#  'he',
#  'really',
#  'belongs',
#  '.']

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
stemmer = PorterStemmer()

# %%
#stemming
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['harri potter miser , lone boy imagin .',
#  '’ shun rel , dursley ’ , rais sinc infant .',
#  '’ forc live cupboard stair , forc wear cousin dudley ’ hand-me-down cloth , forc go neighbour ’ hous rest famili someth fun .',
#  'ye , ’ miser get .',
#  'harri ’ world get turn upsid 11th birthday , howev .',
#  'giant , hagrid , inform harri ’ realli wizard , soon attend hogwart school witchcraft wizardri .',
#  'harri also learn , wizard world , ’ hero .',
#  'infant , evil lord voldemort kill parent tri kill harri .',
#  '’ amaz everyon harri surviv , allegedli destroy voldemort process .',
#  'harri hear , ’ know think .',
#  'howev , everyth hagrid tell turn true , joy heart harri start wizard school septemb .',
#  'quickli becom best friend boy name ron weasley , even make christma , break ton school rule attack troll prevent kill fellow student hermion granger .',
#  'troll incid , three becom insepar , harri amaz found great friend .',
#  'constantli busi tri stay top mound homework , well particip weekli quidditch practic .',
#  'quidditch popular sport among wizard harri youngest quidditch player centuri .',
#  "'s also game harri love anyth els school .",
#  'year progress , three friend set solv mysteri gigant three-head dog guard someth desert corridor school .',
#  'figur valuabl object , sorcer ’ stone , hidden school , although ’ know .',
#  'one professor start act ’ tri steal , quickli take action circumv theft .',
#  'thing come head sneak past viciou , three-head dog go bowel school , determin save stone .',
#  'ron hermion help harri get challeng set forth stop thief , harri must go alon battl professor .',
#  'final get last room , howev , ’ astonish find someon els entir .',
#  'harri forc battl wizard tri kill mani year , lord voldemort .',
#  '’ abl save sorcer ’ stone , although ’ almost kill process .',
#  'school headmast , dumbledor , arriv time save harri .',
#  'school year end spectacularli .',
#  'harri , ron , hermion honor servic school , harri leav go back dursley ’ summer feel ’ final found place realli belong .']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\No_ob0dy\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
sentences1 = nltk.sent_tokenize(paragraph)

# %%
lemmatizer = WordNetLemmatizer()

# %%
#Lemmatization
for i in range(len(sentences1)):
    words = nltk.word_tokenize(sentences1[i])
    words = [lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    sentences1[i] = ' '.join(words)

# %%
sentences1
# Out:
# ['harry potter miserable , lonely boy imagine .',
#  '’ shunned relative , dursley ’ , raised since infant .',
#  '’ forced live cupboard stair , forced wear cousin dudley ’ hand-me-down clothes , forced go neighbour ’ house rest family something fun .',
#  'yes , ’ miserable get .',
#  'harry ’ world get turned upside 11th birthday , however .',
#  'giant , hagrid , informs harry ’ really wizard , soon attending hogwarts school witchcraft wizardry .',
#  'harry also learns , wizarding world , ’ hero .',
#  'infant , evil lord voldemort killed parent tried kill harry .',
#  '’ amazing everyone harry survived , allegedly destroyed voldemort process .',
#  'harry hears , ’ know think .',
#  'however , everything hagrid tell turn true , joyful heart harry start wizarding school september .',
#  'quickly becomes best friend boy named ron weasley , even make christmas , break ton school rule attack troll prevent killing fellow student hermione granger .',
#  'troll incident , three become inseparable , harry amazed found great friend .',
#  'constantly busy trying stay top mound homework , well participating weekly quidditch practice .',
#  'quidditch popular sport among wizard harry youngest quidditch player century .',
#  "'s also game harry love anything else school .",
#  'year progress , three friend set solve mystery gigantic three-headed dog guarding something deserted corridor school .',
#  'figure valuable object , sorcerer ’ stone , hidden school , although ’ know .',
#  'one professor start acting ’ trying steal , quickly take action circumvent theft .',
#  'thing come head sneak past vicious , three-headed dog go bowel school , determined save stone .',
#  'ron hermione help harry get challenge set forth stop thief , harry must go alone battle professor .',
#  'finally get last room , however , ’ astonished find someone else entirely .',
#  'harry forced battle wizard tried kill many year , lord voldemort .',
#  '’ able save sorcerer ’ stone , although ’ almost killed process .',
#  'school headmaster , dumbledore , arrives time save harry .',
#  'school year end spectacularly .',
#  'harry , ron , hermione honored service school , harry leaf go back dursley ’ summer feeling ’ finally found place really belongs .']
