# %% [markdown]
# ### Importing libraries and dataset

# %%
#importing necessary libraries to handle and visualize data
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#for building, training and validating the model
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# %%
df_train = pd.read_csv('car_data.csv')

# %% [markdown]
# ### EDA

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
# Car_Name         301 non-null object
# Year             301 non-null int64
# Selling_Price    301 non-null float64
# Present_Price    301 non-null float64
# Kms_Driven       301 non-null int64
# Fuel_Type        301 non-null object
# Seller_Type      301 non-null object
# Transmission     301 non-null object
# Owner            301 non-null int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.2+ KB

# %%
df_train.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df_train.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
#for categorical data
df_train.describe(include=['object']).transpose()
# Out:
#              count unique     top freq
# Car_Name       301     98    city   26
# Fuel_Type      301      3  Petrol  239
# Seller_Type    301      2  Dealer  195
# Transmission   301      2  Manual  261

# %%
#for numerical features
df_train.describe(include=['int64','float64']).transpose()
# Out:
#                count          mean           std      min      25%      50%  \
# Year           301.0   2013.627907      2.891554  2003.00   2012.0   2014.0
# Selling_Price  301.0      4.661296      5.082812     0.10      0.9      3.6
# Present_Price  301.0      7.628472      8.644115     0.32      1.2      6.4
# Kms_Driven     301.0  36947.205980  38886.883882   500.00  15000.0  32000.0
# Owner          301.0      0.043189      0.247915     0.00      0.0      0.0
#
#                    75%       max
# Year            2016.0    2018.0
# Selling_Price      6.0      35.0
# Present_Price      9.9      92.6
# Kms_Driven     48767.0  500000.0
# Owner              0.0       3.0

# %%
df_train['Owner'] = df_train['Owner'].astype(str)

# %%
df_train.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven
# Year           1.000000       0.236141      -0.047584   -0.524342
# Selling_Price  0.236141       1.000000       0.878983    0.029187
# Present_Price -0.047584       0.878983       1.000000    0.203647
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000

# %%
target = df_train['Selling_Price']
x_data = df_train.drop(['Selling_Price'],axis=1)

# %% [markdown]
# ### Data pre processing

# %%
# save all categorical columns in list
categorical_columns = [col for col in x_data.columns.values if x_data[col].dtype == 'object']

# dataframe with categorical features
x_cat = x_data[categorical_columns]
# dataframe with numerical features
x_num = x_data.drop(categorical_columns, axis=1)

# %%
x_num.hist(figsize=(15,8))
plt.show()

# %%
x_num.skew()
# Out:
# Year            -1.246189
# Present_Price    4.083150
# Kms_Driven       6.436013
# dtype: float64

# %%
sns.boxplot(x_num['Kms_Driven'])

# %%
sns.boxplot(x_num['Present_Price'])

# %%
#func to remove outliers
def rm_out(df):
    for i,val in df.iteritems():
        u_thres = df[i].quantile(q=0.75)+1.5*(df[i].quantile(q=0.75)-df[i].quantile(q=0.25))
        l_thres = df[i].quantile(q=0.25)-1.5*(df[i].quantile(q=0.75)-df[i].quantile(q=0.25))
        df[i] = df[(df[i]>=l_thres) & (df[i]<=u_thres)][i]

# %%
x_num1 = x_num.copy()

# %%
#removing outliers
rm_out(x_num1)

# %%
x_num1.head()
# Out:
#      Year  Present_Price  Kms_Driven
# 0  2014.0           5.59     27000.0
# 1  2013.0           9.54     43000.0
# 2  2017.0           9.85      6900.0
# 3  2011.0           4.15      5200.0
# 4  2014.0           6.87     42450.0

# %%
x_num1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 3 columns):
# Year             294 non-null float64
# Present_Price    287 non-null float64
# Kms_Driven       293 non-null float64
# dtypes: float64(3)
# memory usage: 7.1 KB

# %%
#fill na values
x_num1['Year'] = x_num1['Year'].fillna(x_num1['Year'].mode().iloc[0])
x_num1['Present_Price'] = x_num1['Present_Price'].fillna(x_num1['Present_Price'].mean())
x_num1['Kms_Driven'] = x_num1['Kms_Driven'].fillna(x_num1['Kms_Driven'].mean())

# %%
#normalizing treated and non treated numerical data
x_num = (x_num-x_num.mean()/x_num.std())
x_num1 = (x_num1-x_num1.mean()/x_num1.std())

# %%
#checking for both the skewness
x_num.skew()
# Out:
# Year            -1.246189
# Present_Price    4.083150
# Kms_Driven       6.436013
# dtype: float64

# %%
x_num1.skew()
# Out:
# Year            -0.960353
# Present_Price    0.833819
# Kms_Driven       0.563956
# dtype: float64

# %%
#dummy coding for categorical values
x_cat_dummies = pd.get_dummies(x_cat,drop_first=True)

# %%
sns.distplot(target)

# %%
target.skew()
# Out:
# 2.493422417797524

# %%
target1 = pd.DataFrame(target)
rm_out(target1)

# %%
target1['Selling_Price']=target1['Selling_Price'].fillna(target1['Selling_Price'].mean())

# %%
target1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 1 columns):
# Selling_Price    301 non-null float64
# dtypes: float64(1)
# memory usage: 2.4 KB

# %%
target1.skew()
# Out:
# Selling_Price    0.750712
# dtype: float64

# %% [markdown]
# ### Model 1 with non treated numerical value

# %%
train = pd.concat([x_num,x_cat_dummies],axis = 1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(train,target,test_size=0.30,random_state=2)
print("X_train",X_train.shape)
print("X_test",X_test.shape)
print("Y_train",Y_train.shape)
print("Y_test",Y_test.shape)
# Out:
# X_train (210, 106)
# X_test (91, 106)
# Y_train (210,)
# Y_test (91,)

# %%
#Building Linear Regression model using OLS
model1 = sm.OLS(Y_train,X_train).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:          Selling_Price   R-squared (uncentered):                   0.954
# Model:                            OLS   Adj. R-squared (uncentered):              0.923
# Method:                 Least Squares   F-statistic:                              30.90
# Date:                Sun, 08 Dec 2019   Prob (F-statistic):                    1.95e-56
# Time:                        18:20:47   Log-Likelihood:                         -396.59
# No. Observations:                 210   AIC:                                      961.2
# Df Residuals:                     126   BIC:                                      1242.
# Df Model:                          84
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
#
# Car_Name_Yamaha Fazer              -9.697e-12   2.91e-11     -0.333      0.739   -6.73e-11    4.79e-11
# Car_Name_alto 800                  -5.267e-12   2.55e-11     -0.207      0.837   -5.57e-11    4.52e-11
# Car_Name_alto k10                      0.3505      3.861      0.091      0.928      -7.291       7.992
# Car_Name_amaze                        -0.5161      3.416     -0.151      0.880      -7.276       6.244
# Car_Name_baleno                        0.0259      3.904      0.007      0.995      -7.700       7.752
# Car_Name_brio                          0.3696      3.338      0.111      0.912      -6.237       6.976
# Car_Name_camry                        -7.7160      1.758     -4.390      0.000     -11.194      -4.238
# Car_Name_ciaz                         -0.1868      3.387     -0.055      0.956      -6.889       6.515
# Car_Name_city                         -1.8710      3.372     -0.555      0.580      -8.544       4.802
# Car_Name_corolla                   -1.809e-11    3.4e-11     -0.532      0.596   -8.54e-11    4.93e-11
# Car_Name_corolla altis                -5.5256      3.563     -1.551      0.123     -12.577       1.526
# Car_Name_creta                         0.8163      3.698      0.221      0.826      -6.502       8.134
# Car_Name_dzire                        -1.3849      3.406     -0.407      0.685      -8.126       5.356
# Car_Name_elantra                      -1.1387      4.002     -0.285      0.776      -9.059       6.782
# Car_Name_eon                          -0.0101      3.413     -0.003      0.998      -6.763       6.743
# Car_Name_ertiga                       -1.7622      3.429     -0.514      0.608      -8.548       5.024
# Car_Name_etios cross                  -0.5733      3.578     -0.160      0.873      -7.655       6.508
# Car_Name_etios g                      -0.2730      3.615     -0.076      0.940      -7.427       6.881
# Car_Name_etios gd                     -2.5308      3.871     -0.654      0.514     -10.191       5.129
# Car_Name_etios liva                   -1.0107      3.442     -0.294      0.770      -7.823       5.801
# Car_Name_fortuner                     -6.7320      4.225     -1.593      0.114     -15.094       1.630
# Car_Name_grand i10                     0.7995      3.349      0.239      0.812      -5.827       7.426
# Car_Name_i10                           0.3753      3.395      0.111      0.912      -6.344       7.095
# Car_Name_i20                          -0.8230      3.332     -0.247      0.805      -7.416       5.770
# Car_Name_ignis                         0.4960      3.878      0.128      0.898      -7.178       8.170
# Car_Name_innova                       -1.0959      3.677     -0.298      0.766      -8.372       6.180
# Car_Name_jazz                         -0.3525      3.394     -0.104      0.917      -7.069       6.364
# Car_Name_land cruiser                -40.8622      9.676     -4.223      0.000     -60.010     -21.714
# Car_Name_omni                          0.2986      3.825      0.078      0.938      -7.272       7.869
# Car_Name_ritz                         -0.1897      3.444     -0.055      0.956      -7.006       6.626
# Car_Name_s cross                   -6.831e-12   2.45e-11     -0.278      0.781   -5.54e-11    4.17e-11
# Car_Name_swift                        -0.5266      3.008     -0.175      0.861      -6.480       5.427
# Car_Name_sx4                          -2.5838      3.372     -0.766      0.445      -9.256       4.089
# Car_Name_verna                        -1.4914      3.365     -0.443      0.658      -8.151       5.168
# Car_Name_vitara brezza                -0.4316      3.926     -0.110      0.913      -8.202       7.339
# Car_Name_wagon r                      -1.0031      3.811     -0.263      0.793      -8.545       6.539
# Car_Name_xcent                        -0.0505      3.620     -0.014      0.989      -7.215       7.114
# Fuel_Type_Diesel                       0.6387      2.959      0.216      0.829      -5.217       6.494
# Fuel_Type_Petrol                      -1.2586      2.907     -0.433      0.666      -7.011       4.493
# Seller_Type_Individual                 1.5443      2.400      0.643      0.521      -3.206       6.294
# Transmission_Manual                   -0.1062      0.705     -0.151      0.881      -1.502       1.290
# Owner_1                               -0.5433      1.110     -0.489      0.625      -2.740       1.653
# Owner_3                               -7.7160      1.758     -4.390      0.000     -11.194      -4.238
# ==============================================================================
# Omnibus:                       69.707   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              691.078
# Skew:                           0.934   Prob(JB):                    8.60e-151
# Kurtosis:                      11.688   Cond. No.                     3.36e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.9e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
y_pred = model1.predict(X_test)

# %%
#calculating mean squared error
mse = mean_squared_error(Y_test,y_pred)
print("Mean squared error",mse)
# Out:
# Mean squared error 2.8578612204167313

# %% [markdown]
# ### Model with treated values for target and train variable

# %%
train1 = pd.concat([x_num1,x_cat_dummies],axis = 1)

# %%
X_train1,X_test1,Y_train1,Y_test1 = train_test_split(train1,target1,test_size=0.30,random_state=2)
print("X_train1",X_train1.shape)
print("X_test1",X_test1.shape)
print("Y_train1",Y_train1.shape)
print("Y_test1",Y_test1.shape)
# Out:
# X_train1 (210, 106)
# X_test1 (91, 106)
# Y_train1 (210, 1)
# Y_test1 (91, 1)

# %%
#Building Linear Regression model using OLS
model2 = sm.OLS(Y_train1,X_train1).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:          Selling_Price   R-squared (uncentered):                   0.950
# Model:                            OLS   Adj. R-squared (uncentered):              0.917
# Method:                 Least Squares   F-statistic:                              28.68
# Date:                Sun, 08 Dec 2019   Prob (F-statistic):                    1.48e-54
# Time:                        18:20:48   Log-Likelihood:                         -309.35
# No. Observations:                 210   AIC:                                      786.7
# Df Residuals:                     126   BIC:                                      1068.
# Df Model:                          84
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Year                                   0.0002      0.002      0.101      0.920      -0.004       0.005
# Present_Price                          0.3533      0.062      5.710      0.000       0.231       0.476
# Kms_Driven                         -2.065e-05   6.26e-06     -3.298      0.001    -3.3e-05   -8.26e-06
# Car_Name_Activa 3g                     0.4698      1.722      0.273      0.785      -2.938       3.877
# Car_Name_Activa 4g                     0.2503      1.984      0.126      0.900      -3.676       4.177
# Car_Name_Bajaj  ct 100                 0.4694      1.931      0.243      0.808      -3.352       4.291
# Car_Name_Bajaj Avenger 150          1.895e-12    5.1e-12      0.372      0.711    -8.2e-12     1.2e-11
# Car_Name_Bajaj Avenger 150 street   -2.88e-11   1.76e-11     -1.637      0.104   -6.36e-11    6.01e-12
# Car_Name_Bajaj Avenger 220             0.1660      1.938      0.086      0.932      -3.670       4.002
# Car_Name_Bajaj Avenger 220 dtsi        0.2869      1.931      0.149      0.882      -3.535       4.109
# Car_Name_Bajaj Avenger Street 220  -7.647e-12   7.28e-12     -1.051      0.295   -2.21e-11    6.76e-12
# Car_Name_corolla altis                 1.1312      2.332      0.485      0.628      -3.484       5.746
# Car_Name_creta                         8.6222      2.411      3.576      0.000       3.851      13.394
# Car_Name_dzire                         3.6463      2.222      1.641      0.103      -0.751       8.044
# Car_Name_elantra                       7.6325      2.625      2.907      0.004       2.437      12.828
# Car_Name_eon                           3.1178      2.210      1.411      0.161      -1.256       7.492
# Car_Name_ertiga                        4.6191      2.237      2.065      0.041       0.193       9.045
# Car_Name_etios cross                   3.9787      2.328      1.709      0.090      -0.628       8.585
# Car_Name_etios g                       3.9444      2.353      1.677      0.096      -0.711       8.600
# Car_Name_etios gd                      3.0116      2.530      1.190      0.236      -1.995       8.019
# Car_Name_etios liva                    3.2045      2.243      1.429      0.156      -1.235       7.644
# Car_Name_fortuner                      3.0347      2.224      1.365      0.175      -1.366       7.436
# Car_Name_grand i10                     4.6928      2.172      2.160      0.033       0.394       8.992
# Car_Name_i10                           3.5806      2.201      1.627      0.106      -0.776       7.937
# Car_Name_i20                           3.9312      2.168      1.813      0.072      -0.359       8.221
# Car_Name_ignis                         4.2176      2.523      1.671      0.097      -0.776       9.211
# Car_Name_innova                        2.5508      2.293      1.112      0.268      -1.987       7.089
# Car_Name_jazz                          4.4826      2.200      2.038      0.044       0.129       8.836
# Car_Name_land cruiser                  3.3053      2.518      1.313      0.192      -1.678       8.289
# Car_Name_omni                          2.6185      2.493      1.050      0.296      -2.315       7.552
# Car_Name_ritz                          3.2626      2.240      1.457      0.148      -1.170       7.695
# Car_Name_s cross                    1.393e-13   4.03e-13      0.346      0.730   -6.57e-13    9.36e-13
# Car_Name_swift                         3.6192      1.947      1.859      0.065      -0.234       7.472
# Car_Name_sx4                           2.5138      2.207      1.139      0.257      -1.853       6.881
# Car_Name_verna                         4.3641      2.199      1.985      0.049       0.012       8.716
# Car_Name_vitara brezza                 6.0283      2.568      2.347      0.020       0.946      11.110
# Car_Name_wagon r                       2.1122      2.488      0.849      0.397      -2.811       7.035
# Car_Name_xcent                         4.3198      2.355      1.834      0.069      -0.342       8.981
# Fuel_Type_Diesel                      -0.3833      1.961     -0.195      0.845      -4.265       3.498
# Fuel_Type_Petrol                      -1.4598      1.925     -0.758      0.450      -5.270       2.350
# Seller_Type_Individual                 1.6061      1.587      1.012      0.314      -1.535       4.747
# Transmission_Manual                    0.3242      0.428      0.758      0.450      -0.523       1.171
# Owner_1                               -0.5134      0.733     -0.700      0.485      -1.965       0.938
# Owner_3                                0.4768      0.995      0.479      0.633      -1.492       2.445
# ==============================================================================
# Omnibus:                       45.549   Durbin-Watson:                   1.828
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              577.532
# Skew:                           0.246   Prob(JB):                    3.89e-126
# Kurtosis:                      11.109   Cond. No.                     5.87e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.51e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
y_pred1 = model2.predict(X_test1)

# %%
#calculating mean squared error
mse1 = mean_squared_error(Y_test1,y_pred1)
print("Mean squared error",mse1)
# Out:
# Mean squared error 1.4919283806659371
